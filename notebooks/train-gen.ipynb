# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd /content/drive/MyDrive/Thesis/run-2/

# %%
import os

# Change to the target directory where you want to clone the repository
os.chdir('/content/drive/MyDrive/Thesis/run-2/')

# Clone the cGAN-Seg repository
# IMPORTANT: Replace <YOUR_CGAN_SEG_REPO_URL> with the actual URL of the repository
# !rm -r cGAN-Seg
# !git clone https://github.com/anik-m/cGAN-Seg cGAN-Seg
# Out:
# Cloning into 'cGAN-Seg'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 82 (delta 36), reused 65 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 601.87 KiB | 774.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
#/content/drive/MyDrive/Thesis/run-2/cGAN-Seg/
# !pip install -r /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torch~=2.1.2 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0, 2.12.1, 2.13.0)
# ERROR: No matching distribution found for torch~=2.1.2

# %%
#deepbacs-1 dataset train
#!python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir  /content/drive/MyDrive/Thesis/run-2/deepbacs-1/train/  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 50 --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/output/

# %%
#deepbacs-2 fluorescence dataset train
#!python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir  /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/train/full_images/  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 50 --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/output/

# %%
#deepbacs-2 brightfield dataset train
#!python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir  /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/train/full_images/  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 50 --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/output/

# %%
#deepbacs-3 SplineDist dataset train
#!python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir  /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/train/  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 50 --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/output/

# %%
#deepbacs-3 pix2pix dataset train
#!python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir  /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/train/  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 50 --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/output/

# %%
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/annotation_to_mask.py --input /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train/annotations --output /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train/masks/
# Out:
# Found 153 XML files. Starting conversion...
# Successfully generated 153 masks in '/content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train/masks/'.

# %%
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/annotation_to_mask.py --input /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/test/individual_treatment/annotations --output /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/test/individual_treatment/masks
# Out:
# Found 50 XML files. Starting conversion...
# Successfully generated 50 masks in '/content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/test/individual_treatment/masks'.

# %%
#phenotype dataset train
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py --seg_model UNET --train_set_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train  --lr 0.0001 --p_vanilla 0.2 --p_diff 0.2 --patience 100 --output_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/output/
# Out:
# /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/train.py:114: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   grad_scaler = torch.cuda.amp.GradScaler(enabled=True)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# INFO: Start training ...
# ...
