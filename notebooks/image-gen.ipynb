# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Change to the target directory where you want to clone the repository
os.chdir('/content/drive/MyDrive/Thesis/run-2/')

# Clone the cGAN-Seg repository
# IMPORTANT: Replace <YOUR_CGAN_SEG_REPO_URL> with the actual URL of the repository
# !rm -r cGAN-Seg
# !git clone https://github.com/anik-m/cGAN-Seg cGAN-Seg
# Out:
# Cloning into 'cGAN-Seg'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 85 (delta 38), reused 67 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 602.85 KiB | 18.84 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !pip install -r /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.1 MB/s eta 0:00:00
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torch~=2.1.2 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0, 2.12.1, 2.13.0)
# ERROR: No matching distribution found for torch~=2.1.2

# %%
#generation model for deepbacs-1
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/train/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/train/generated_images/
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/test/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-1/test/generated_images/
# Out:
#   0% 0/19 [00:00<?, ?it/s][ WARN:0@22.594] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@22.594] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#   5% 1/19 [00:04<01:28,  4.91s/it][ WARN:0@27.650] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@27.651] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#  11% 2/19 [00:08<01:13,  4.34s/it][ WARN:0@31.613] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@31.613] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
# ...

# %%
#generation model for deepbacs-2(fluorescence)
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/train/full_images/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/train/full_images/generated_images/
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/test/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/fluorescence_dataset/test/generated_images/
# Out:
#   0% 0/7 [00:00<?, ?it/s][ WARN:0@13.046] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
#  14% 1/7 [00:03<00:19,  3.31s/it][ WARN:0@16.276] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
#  29% 2/7 [00:06<00:15,  3.11s/it][ WARN:0@19.862] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
# 100% 7/7 [00:20<00:00,  2.98s/it]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
#generation model for deepbacs-2(brightfield)
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/train/full_images/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/train/full_images/generated_images/
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/test/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-2/brightfield_dataset/test/generated_images/
# Out:
#   0% 0/7 [00:00<?, ?it/s][ WARN:0@12.574] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
# [ WARN:0@14.313] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@14.313] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#  14% 1/7 [00:04<00:27,  4.55s/it][ WARN:0@17.086] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
# [ WARN:0@18.558] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@18.558] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#  29% 2/7 [00:07<00:17,  3.50s/it][ WARN:0@20.498] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Incorrect count for "ColorMap"; tag ignored
# ...

# %%
#generation model for deepbacs-3(SplineDist)
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/train/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/train/generated_images/
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/test/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/SplineDist_dataset/test/generated_images/
# Out:
#   0% 0/32 [00:00<?, ?it/s][ WARN:0@13.171] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@13.171] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#   3% 1/32 [00:02<01:31,  2.94s/it][ WARN:0@16.040] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@16.040] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
#   6% 2/32 [00:05<01:20,  2.70s/it][ WARN:0@18.513] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50838 (0xc696) encountered
# [ WARN:0@18.513] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50839 (0xc697) encountered
# ...

# %%
#generation model for deepbacs-3(pix2pix)
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/train/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/train/generated_images/
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/test/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/deepbacs-3/pix2pix_dataset/test/generated_images/
# Out:
# 100% 80/80 [02:47<00:00,  2.10s/it]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# FID Score: 1.796849
# 100% 10/10 [00:20<00:00,  2.07s/it]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
#generation model for objectdetectiondataset
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/train/generated_images/
# Out:
# 100% 153/153 [02:13<00:00,  1.15it/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# FID Score: 4.068975

# %%
# !python /content/drive/MyDrive/Thesis/run-2/cGAN-Seg/test_generation_model.py --test_set_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/test/individual_treatment/ --gen_ckpt_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/output/Gen.pth --output_dir /content/drive/MyDrive/Thesis/run-2/objectdetectionphenotypingdataset/test/individual_treatment/generated_images/
# Out:
# 100% 50/50 [00:44<00:00,  1.12it/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# FID Score: 58.370934
